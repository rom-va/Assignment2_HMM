# %%
# Group members: Romina and Sahand. feb 2025.

# %% [markdown]
# ## Some comparisons of filtering and smoothing (can be with or without the viewer)
#
# ### Hint for your task 2)
# #### You must implement your filtering / smoothing in the HMMFilter / HMMSmoother classes in the file Filters. For the filter, this means also that you can use the visualisation through the Localizer, but you can call filter / smooth also directly from here, without the Localiser. Note also, that you must make use of the given models and the robot simulator in RobotSim!

# %%
from models import *
from Filters import HMMFilter, HMMSmoother

import numpy as np
import matplotlib.pyplot as plt
import random

# %%
# Simple forward filtering: Test
np.set_printoptions(threshold=np.inf)

# Set up: Models
grid_size = 8
sm = StateModel(grid_size, grid_size)
tm = TransitionModel(sm)
#om = ObservationModel_UF.ObservationModelUF(sm)
om = ObservationModel_NUF.ObservationModel(sm)

# The initial position of the robot is a random cell
true_states = []
true_states.append(random.randint(0, sm.get_num_of_states() - 1))
sense = []
sense.append(None)

number_steps = 5 # Number of steps the robot will take in this test

# We set up an f matrix to store the distributions at each step
f = np.zeros((sm.get_num_of_states(), number_steps + 1))
f[:,0] = np.ones(sm.get_num_of_states()) / (sm.get_num_of_states()) # Start with an uniform distribution for every state

# The robot simulator is started at the first position
rs = RobotSim(true_states[0], sm)

# Initializing HMM filter
filter_HMM = HMMFilter(f[:,0], tm, om, sm)

# We will store the guess at each time slice
guess = []
guess.append((0,0)) # We do not make a guess in the starting state (So) because we have not made any observations

counter_correct_guesses = 0
sum_manhattan_d = 0

for i in range(1, number_steps + 1):
    true_states.append(rs.move_once(tm))
    sense.append(rs.sense_in_current_state(om))
    f[:,i] = filter_HMM.filter(sense[i])

    # Take a guess (Code taken from Localizer.py)
    fPositions = f[:,i].copy()        
    for state in range(0, sm.get_num_of_states(), 4) :
        fPositions[state:state+4] = sum(fPositions[state:state+4])
        
    guess.append(sm.state_to_position(np.argmax(fPositions))) # Guesses position with greatest probability
    
    ret = False  
    tsX, tsY, tsH = sm.state_to_pose(true_states[i])
    srX = -1
    srY = -1
    if sense[i] != None:
        srX, srY = sm.reading_to_position(sense[i])        
        ret = True
    else:
        ret = False        
    eX, eY = guess[i]
    
    error = abs(tsX-eX)+abs(tsY-eY) # Absolute error from True state and Guessed state (Manhattan distance)
    sum_manhattan_d = sum_manhattan_d + error
    if (eX == tsX and eY == tsY):
        counter_correct_guesses = counter_correct_guesses + 1

    # Print relevant information for each step (Comment if not necessary)
    #print(str(i) + " step:")
    #print("\t True State: " + "x:" + str(tsX) + " y:" + str(tsY) + " h:" + str(tsH))
    #if (srX or srY < 0):
    #    print("\t Reading: None")    
    #else: 
    #    print("\t Reading: "+ "x:" + str(srX) + " y:" + str(srY))
    #print("\t Guess: "+ "x:" + str(eX)+ " y:"  + str(eY))
    #print("\t Manhattan distance: " + str(error))
    #if (eX == tsX and eY == tsY):
    #    print("\t Guessed correctly")
    #else:
    #    print("\t Guessed incorrectly")
    #print("------------------------------------------")

# Summary
print("Summary. Forward Filtering")
print("\t Grid size: " + str(grid_size) + "x" + str(grid_size) + " | Number of steps taken: " + str(number_steps))
print("\t Correct estimates: Total = " + str(counter_correct_guesses) + " | Rate = " + str(counter_correct_guesses/number_steps * 100) + " %")
print("\t Average Manhattan distance: " + str(sum_manhattan_d/number_steps))
# Out:
# Summary. Forward Filtering
# 	 Grid size: 8x8 | Number of steps taken: 5
# 	 Correct estimates: Total = 1 | Rate = 20.0 %
# 	 Average Manhattan distance: 1.4

# %%
# Smoothing. Test # 1
# We use the observations and distributions gathered from the filtering test above. Run before this block.

# Initializing HMM smoother (to call the smooth() method)
smoother_HMM = HMMSmoother(tm, om, sm)

k = 0 # fk distribution to be smoothed
# sensor_r_seq is the sequence (array) with the t-k sensor readings for smoothing
sensor_r_seq = sense[k: len(sense)]
fk = f[:,k]
fs = smoother_HMM.smooth(sensor_r_seq, fk)

# Summary. Smoothing test for one time slice in the past
print("Smoothing for step " + str(k) + " in " + str(number_steps) + " steps")
tsX, tsY, tsH = sm.state_to_pose(true_states[k])
print("\t True State: " + "x:" + str(tsX) + " y:" + str(tsY) + " h:" + str(tsH))
eX, eY = guess[k]
print("\t Guessed State: " + "x:" + str(eX)+ " y:"  + str(eY))

print(fs)
print(sum(fs))

# New Guess
#neX, neY = new_guess 
#print("\t New Guessed State: " + "x:" + str(neX)+ " y:"  + str(neY))

#print("Old probability distribution:")
#print(fk)
#print("Smoothed probability distribution:")
#print(fs)
#print("True position:")
 # Get pose from true state
#print("True hidden state: "+ str(tsX) + " " + str(tsY) + " " + str(tsH))
# Out:
# Smoothing for step 0 in 5 steps
# 	 True State: x:6 y:0 h:3
# 	 Guessed State: x:0 y:0
# [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  4.28849356e-03 9.18962905e-04 9.18962905e-04 2.04213979e-03
#  9.08370404e-04 1.29767201e-04 1.29767201e-04 1.29767201e-04
#  1.73085911e-04 2.47265587e-05 2.47265587e-05 2.47265587e-05
#  9.79116678e-05 1.39873811e-05 1.39873811e-05 1.39873811e-05
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  1.07386004e-02 2.42493715e-03 2.32297721e-03 5.16217157e-03
#  9.14701089e-03 1.58099571e-03 1.55980152e-03 3.31020705e-03
#  2.06300003e-03 3.24306076e-04 3.12316892e-04 4.23545921e-04
#  8.96702568e-04 1.31128109e-04 1.31128109e-04 1.52322302e-04
#  3.99639460e-06 2.28365406e-06 2.28365406e-06 1.42728379e-05
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  1.74163712e-02 5.27157402e-03 4.85321655e-03 9.18038726e-03
#  2.56693180e-02 4.62486727e-03 4.46820092e-03 8.80733275e-03
#  9.94782819e-03 1.83746084e-03 1.74669205e-03 3.72299746e-03
#  1.59062461e-03 2.73758232e-04 2.84034675e-04 5.72037390e-04
#  9.81696014e-05 3.26141486e-05 3.26141486e-05 1.62743587e-04
#  1.99819730e-06 1.99819730e-06 1.99819730e-06 1.39873811e-05
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  1.99379087e-02 9.49502773e-03 7.35378155e-03 1.22622393e-02
#  1.79182427e-02 5.70065992e-03 5.36066350e-03 1.25950896e-02
#  5.93747592e-03 2.08983798e-03 2.00450163e-03 7.43701140e-03
#  3.18554463e-03 9.38876583e-04 9.85284117e-04 3.62350597e-03
#  3.94302417e-04 2.58685990e-04 2.60398730e-04 1.67347276e-03
#  7.64813616e-05 7.64813616e-05 7.64813616e-05 5.35369531e-04
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  2.32688771e-02 1.37170375e-02 1.12890895e-02 1.60916680e-02
#  1.25106787e-02 5.77355852e-03 7.90598917e-03 1.69869612e-02
#  9.86047797e-03 3.77544120e-03 4.24787213e-03 1.04867366e-02
#  6.07730141e-03 1.75655172e-03 1.97416703e-03 6.40133275e-03
#  2.10303238e-03 1.03291680e-03 1.09847225e-03 6.09474657e-03
#  1.58219165e-04 1.58219165e-04 1.58219165e-04 1.10753415e-03
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  2.25443061e-02 1.61210931e-02 1.48178708e-02 1.78277567e-02
#  2.32027425e-02 1.13827869e-02 1.17522711e-02 2.60347050e-02
#  1.18008631e-02 5.83759952e-03 5.30067873e-03 1.48517431e-02
#  1.13762262e-02 4.34531111e-03 4.34663789e-03 1.26837801e-02
#  7.11481271e-03 2.66974416e-03 2.80536058e-03 1.41075241e-02
#  1.24846818e-03 1.24846818e-03 1.24846818e-03 8.73927726e-03
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  2.38914262e-02 2.34666318e-02 2.43162206e-02 2.38914262e-02
#  1.81361547e-02 1.37083816e-02 1.80169973e-02 2.26830853e-02
#  1.44475598e-02 9.84307704e-03 1.21387584e-02 2.13608438e-02
#  7.57917530e-03 5.24421966e-03 5.82371139e-03 1.16695948e-02
#  8.56199483e-03 3.85289767e-03 4.83383696e-03 1.69992499e-02
#  5.18591332e-03 2.33366099e-03 2.33366099e-03 1.08904180e-02
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# 0.9999999999999998

# %%
# Other tools

# %%
# Tests regarding the observation diagonal matrices Oi

sm = StateModel( 8, 8)
loc = Localizer( sm, 0)

np.set_printoptions(threshold=np.inf)
om = ObservationModel_UF.ObservationModelUF(sm)
o = om.get_o_reading(None) # When this model fails, the probability of being in all 256 states is the same
print(o.shape)
print(o)
om = ObservationModel_NUF.ObservationModel(sm) # When this model fails, the probability of being in all 256 states is different
o = om.get_o_reading(None)
print(o.shape)
print(o)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 4
#       1 # Tests regarding the observation diagonal matrices Oi
#       3 sm = StateModel( 8, 8)
# ----> 4 loc = Localizer( sm, 0)
#       6 np.set_printoptions(threshold=np.inf)
#       7 om = ObservationModel_UF.ObservationModelUF(sm)
#
# NameError: name 'Localizer' is not defined

# %%
sm = StateModel( 8, 8)
loc = Localizer( sm, 0)

om = ObservationModel_UF.ObservationModelUF(sm)
o = om.get_o_reading(None) # When this model fails, the probability of being in all 256 states is the same
print(o.shape)

f = np.ones(sm.get_num_of_states()) / (sm.get_num_of_states()) 
# print(f) # The initial probability distribution of the hidden states is uniform
print(f.shape)

tm = TransitionModel(sm)
T = tm.get_T()
print(T.shape)
# Out:
# (256, 256)
# (256,)
# (256, 256)

# %%
# In this cell, you can write your own "main" to run and evaluate your 
# implementation without using the visualisation (should be considerably faster!)
from models import *
from Filters import HMMFilter, HMMSmoother

import numpy as np
import matplotlib.pyplot as plt
import random

# Relevant models
sm = StateModel(8, 8)
tm = TransitionModel(sm)
#om = ObservationModel_UF.ObservationModelUF(sm)
om = ObservationModel_NUF.ObservationModel(sm)

true_states = []
true_states.append(random.randint(0, sm.get_num_of_states() - 1))
sense = []
sense.append(None)

number_steps = 500

f = np.zeros((sm.get_num_of_states(), number_steps + 1))
f[:,0] = np.ones(sm.get_num_of_states()) / (sm.get_num_of_states()) # Start with an uniform distribution for every state

# The robot simulator is started at some true state
rs = RobotSim(true_states[0], sm)

# Initializing HMM filter (to call the filter() method)
filter_HMM = HMMFilter(f[:,0], tm, om, sm)
guess = []
guess.append(-1)
np.set_printoptions(threshold=np.inf)

counter_correct_guesses = 0

for i in range(1, number_steps): # For number_steps steps
    true_states.append(rs.move_once(tm))
    sense.append(rs.sense_in_current_state(om))
    f[:,i] = filter_HMM.filter(sense[i]) # We update the distribution

    # Now, we take a guess (taken from Localizer.py)
    print("Iteration: " + str(i))
    fPositions = f[:,i].copy()
        
    for state in range(0, sm.get_num_of_states(), 4) :
        fPositions[state:state+4] = sum(fPositions[state:state+4])
        
    guess.append(sm.state_to_position(np.argmax(fPositions))) # Guesses position with greatest probability
    
    ret = False  # in case the sensor reading is "nothing" this is kept...
    tsX, tsY, tsH = sm.state_to_pose(true_states[i]) # Get pose from true state
    print("True hidden state: "+ str(tsX) + " " + str(tsY) + " " + str(tsH))
    srX = -1
    srY = -1
    if sense[i] != None: # Try to get the reading that was sensed
        srX, srY = sm.reading_to_position(sense[i])
        print("Reading: "+ str(srX) + " " + str(srY))
        ret = True
    else:
        ret = False
        print("Reading: None")
    eX, eY = guess[i] # Gets position guessed
    print("Guess: "+ str(eX)+ " "  + str(eY))
    error = abs(tsX-eX)+abs(tsY-eY) # Absolute error from True state and Guessed state
    if (eX == tsX and eY == tsY):
        print("Guessed correctly")
        counter_correct_guesses = counter_correct_guesses + 1
    else:
        ret = True
        print("Guessed incorrectly")

# Print
#print("Correct guesses = " + str(counter_correct_guesses))
#print("True hidden states:")
#print(true_states)
print("Observations:")
print(sense)
#print("Guesses:")
#print(guess)
#print(f)
#print(np.sum(f[:,9]))
print(f[:,9])
print("---------------------------------------------")

# 2. Smoothing. For the smoothing part, we will be using the observations and f distributions from the filtering
# Initializing HMM smoother (to call the smooth() method)
smoother_HMM = HMMSmoother(tm, om, sm)

k = 95 # fk distribution with be smoothed
# sensor_r_seq is the sequence (array) with the t-k sensor readings for smoothing
sensor_r_seq = sense[k: len(sense)]
#print(sensor_r_seq)
fk = f[:,k]
#print(fk)
#print(np.sum(fk))
fs = smoother_HMM.smooth(sensor_r_seq, fk)
print(fs)
#print("Old probability distribution:")
#print(fk)
#print("Smoothed probability distribution:")
#print(fs)
#print("True position:")
tsX, tsY, tsH = sm.state_to_pose(true_states[k]) # Get pose from true state
#print("True hidden state: "+ str(tsX) + " " + str(tsY) + " " + str(tsH))
# Out:
# Iteration: 1
# True hidden state: 6 4 3
# Reading: 7 3
# Guess: 7 3
# Guessed incorrectly
# Iteration: 2
# True hidden state: 7 4 0
# Reading: 5 5
# Guess: 6 4
# Guessed incorrectly
# Iteration: 3
# True hidden state: 6 4 2
# Reading: None
# Guess: 7 5
# Guessed incorrectly
# Iteration: 4
# True hidden state: 5 4 2
# Reading: 3 3
# Guess: 3 3
# Guessed incorrectly
# Iteration: 5
# True hidden state: 4 4 2
# Reading: 5 5
# Guess: 4 4
# Guessed correctly
# Iteration: 6
# True hidden state: 3 4 2
# Reading: 4 4
# Guess: 3 4
# Guessed correctly
# Iteration: 7
# True hidden state: 2 4 2
# Reading: 2 4
# Guess: 2 4
# Guessed correctly
# Iteration: 8
# True hidden state: 2 3 3
# Reading: 4 5
# Guess: 3 4
# Guessed incorrectly
# Iteration: 9
# True hidden state: 2 2 3
# Reading: 2 3
# Guess: 2 3
# Guessed incorrectly
# Iteration: 10
# True hidden state: 2 1 3
# Reading: None
# Guess: 0 4
# Guessed incorrectly
# Iteration: 11
# True hidden state: 2 0 3
# Reading: None
# Guess: 0 3
# Guessed incorrectly
# Iteration: 12
# True hidden state: 3 0 0
# Reading: None
# Guess: 0 2
# Guessed incorrectly
# Iteration: 13
# True hidden state: 4 0 0
# Reading: None
# Guess: 0 7
# Guessed incorrectly
# Iteration: 14
# True hidden state: 3 0 2
# Reading: None
# Guess: 0 0
# Guessed incorrectly
# Iteration: 15
# True hidden state: 2 0 2
# Reading: 0 0
# Guess: 0 0
# Guessed incorrectly
# Iteration: 16
# True hidden state: 1 0 2
# Reading: 1 2
# Guess: 0 1
# Guessed incorrectly
# Iteration: 17
# True hidden state: 0 0 2
# Reading: None
# Guess: 0 2
# Guessed incorrectly
# Iteration: 18
# True hidden state: 0 1 1
# Reading: 0 2
# Guess: 0 3
# Guessed incorrectly
# Iteration: 19
# True hidden state: 1 1 0
# Reading: 3 0
# Guess: 2 0
# Guessed incorrectly
# Iteration: 20
# True hidden state: 0 1 2
# Reading: 2 2
# Guess: 2 2
# Guessed incorrectly
# Iteration: 21
# True hidden state: 0 2 1
# Reading: None
# Guess: 4 0
# Guessed incorrectly
# Iteration: 22
# True hidden state: 0 3 1
# Reading: None
# Guess: 0 0
# Guessed incorrectly
# Iteration: 23
# True hidden state: 0 4 1
# Reading: None
# Guess: 1 0
# Guessed incorrectly
# Iteration: 24
# True hidden state: 1 4 0
# Reading: 3 5
# Guess: 1 3
# Guessed incorrectly
# Iteration: 25
# True hidden state: 1 5 1
# Reading: 2 5
# Guess: 1 4
# Guessed incorrectly
# Iteration: 26
# True hidden state: 1 6 1
# Reading: 3 6
# Guess: 3 5
# Guessed incorrectly
# Iteration: 27
# True hidden state: 1 7 1
# Reading: 2 5
# Guess: 2 5
# Guessed incorrectly
# Iteration: 28
# True hidden state: 2 7 0
# Reading: 2 7
# Guess: 2 7
# Guessed correctly
# Iteration: 29
# True hidden state: 3 7 0
# Reading: None
# Guess: 2 7
# Guessed incorrectly
# Iteration: 30
# True hidden state: 4 7 0
# Reading: 4 7
# Guess: 4 7
# Guessed correctly
# Iteration: 31
# True hidden state: 5 7 0
# Reading: 4 5
# Guess: 5 7
# Guessed correctly
# Iteration: 32
# True hidden state: 6 7 0
# Reading: 5 7
# Guess: 5 7
# Guessed incorrectly
# Iteration: 33
# True hidden state: 7 7 0
# Reading: None
# Guess: 6 7
# Guessed incorrectly
# Iteration: 34
# True hidden state: 7 6 3
# Reading: 5 6
# Guess: 6 7
# Guessed incorrectly
# Iteration: 35
# True hidden state: 7 5 3
# Reading: None
# Guess: 5 7
# Guessed incorrectly
# Iteration: 36
# True hidden state: 7 4 3
# Reading: None
# Guess: 6 7
# Guessed incorrectly
# Iteration: 37
# True hidden state: 7 3 3
# Reading: 6 4
# Guess: 7 5
# Guessed incorrectly
# Iteration: 38
# True hidden state: 7 2 3
# Reading: None
# Guess: 7 4
# Guessed incorrectly
# Iteration: 39
# True hidden state: 7 1 3
# Reading: None
# Guess: 7 3
# Guessed incorrectly
# Iteration: 40
# True hidden state: 7 0 3
# Reading: None
# Guess: 7 2
# Guessed incorrectly
# Iteration: 41
# True hidden state: 7 1 1
# Reading: 6 2
# Guess: 7 1
# Guessed correctly
# Iteration: 42
# True hidden state: 7 2 1
# Reading: None
# Guess: 7 0
# Guessed incorrectly
# Iteration: 43
# True hidden state: 7 3 1
# Reading: None
# Guess: 7 1
# Guessed incorrectly
# Iteration: 44
# True hidden state: 7 4 1
# Reading: None
# Guess: 7 0
# Guessed incorrectly
# Iteration: 45
# True hidden state: 7 5 1
# Reading: 5 5
# Guess: 7 3
# Guessed incorrectly
# Iteration: 46
# True hidden state: 7 6 1
# Reading: None
# Guess: 7 4
# Guessed incorrectly
# Iteration: 47
# True hidden state: 7 5 3
# Reading: None
# Guess: 7 5
# Guessed correctly
# Iteration: 48
# True hidden state: 7 4 3
# Reading: None
# Guess: 7 6
# Guessed incorrectly
# Iteration: 49
# True hidden state: 7 3 3
# Reading: 5 1
# Guess: 6 0
# Guessed incorrectly
# Iteration: 50
# True hidden state: 7 2 3
# Reading: 6 3
# Guess: 7 2
# Guessed correctly
# Iteration: 51
# True hidden state: 7 1 3
# Reading: None
# Guess: 7 1
# Guessed correctly
# Iteration: 52
# True hidden state: 6 1 2
# Reading: 7 1
# Guess: 7 0
# Guessed incorrectly
# Iteration: 53
# True hidden state: 5 1 2
# Reading: None
# Guess: 7 1
# Guessed incorrectly
# Iteration: 54
# True hidden state: 5 0 3
# Reading: 5 1
# Guess: 5 0
# Guessed correctly
# Iteration: 55
# True hidden state: 4 0 2
# Reading: None
# Guess: 4 0
# Guessed correctly
# Iteration: 56
# True hidden state: 3 0 2
# Reading: None
# Guess: 7 0
# Guessed incorrectly
# Iteration: 57
# True hidden state: 2 0 2
# Reading: None
# Guess: 6 0
# Guessed incorrectly
# Iteration: 58
# True hidden state: 1 0 2
# Reading: 2 0
# Guess: 2 0
# Guessed incorrectly
# Iteration: 59
# True hidden state: 0 0 2
# Reading: 2 1
# Guess: 1 0
# Guessed incorrectly
# Iteration: 60
# True hidden state: 0 1 1
# Reading: None
# Guess: 0 0
# Guessed incorrectly
# Iteration: 61
# True hidden state: 0 2 1
# Reading: 0 4
# Guess: 0 2
# Guessed correctly
# Iteration: 62
# True hidden state: 0 3 1
# Reading: 0 3
# Guess: 0 3
# Guessed correctly
# Iteration: 63
# True hidden state: 0 4 1
# Reading: 0 4
# Guess: 0 4
# Guessed correctly
# Iteration: 64
# True hidden state: 1 4 0
# Reading: 0 2
# Guess: 0 3
# Guessed incorrectly
# Iteration: 65
# True hidden state: 1 3 3
# Reading: 1 4
# Guess: 0 2
# Guessed incorrectly
# Iteration: 66
# True hidden state: 1 2 3
# Reading: None
# Guess: 0 1
# Guessed incorrectly
# Iteration: 67
# True hidden state: 1 1 3
# Reading: 1 2
# Guess: 0 2
# Guessed incorrectly
# Iteration: 68
# True hidden state: 1 0 3
# Reading: 3 0
# Guess: 2 1
# Guessed incorrectly
# Iteration: 69
# True hidden state: 2 0 0
# Reading: 0 0
# Guess: 1 1
# Guessed incorrectly
# Iteration: 70
# True hidden state: 2 1 1
# Reading: 2 3
# Guess: 1 2
# Guessed incorrectly
# Iteration: 71
# True hidden state: 2 2 1
# Reading: None
# Guess: 0 2
# Guessed incorrectly
# Iteration: 72
# True hidden state: 2 3 1
# Reading: 2 3
# Guess: 1 4
# Guessed incorrectly
# Iteration: 73
# True hidden state: 1 3 2
# Reading: 1 4
# Guess: 0 4
# Guessed incorrectly
# Iteration: 74
# True hidden state: 0 3 2
# Reading: None
# Guess: 0 5
# Guessed incorrectly
# Iteration: 75
# True hidden state: 0 2 3
# Reading: 0 1
# Guess: 0 2
# Guessed correctly
# Iteration: 76
# True hidden state: 0 1 3
# Reading: 0 1
# Guess: 0 1
# Guessed correctly
# Iteration: 77
# True hidden state: 0 2 1
# Reading: 0 2
# Guess: 0 2
# Guessed correctly
# Iteration: 78
# True hidden state: 0 3 1
# Reading: None
# Guess: 0 3
# Guessed correctly
# Iteration: 79
# True hidden state: 0 4 1
# Reading: 0 4
# Guess: 0 4
# Guessed correctly
# Iteration: 80
# True hidden state: 0 3 3
# Reading: 2 1
# Guess: 0 3
# Guessed correctly
# Iteration: 81
# True hidden state: 1 3 0
# Reading: 1 4
# Guess: 0 4
# Guessed incorrectly
# Iteration: 82
# True hidden state: 2 3 0
# Reading: 0 1
# Guess: 0 1
# Guessed incorrectly
# Iteration: 83
# True hidden state: 2 2 3
# Reading: None
# Guess: 0 0
# Guessed incorrectly
# Iteration: 84
# True hidden state: 2 3 1
# Reading: 3 5
# Guess: 1 4
# Guessed incorrectly
# Iteration: 85
# True hidden state: 2 4 1
# Reading: 1 2
# Guess: 2 4
# Guessed correctly
# Iteration: 86
# True hidden state: 2 5 1
# Reading: 1 7
# Guess: 2 5
# Guessed correctly
# Iteration: 87
# True hidden state: 3 5 0
# Reading: None
# Guess: 2 6
# Guessed incorrectly
# Iteration: 88
# True hidden state: 3 6 1
# Reading: 3 5
# Guess: 2 7
# Guessed incorrectly
# Iteration: 89
# True hidden state: 3 5 3
# Reading: 2 6
# Guess: 2 6
# Guessed incorrectly
# Iteration: 90
# True hidden state: 3 4 3
# Reading: 3 5
# Guess: 2 5
# Guessed incorrectly
# Iteration: 91
# True hidden state: 3 5 1
# Reading: 4 6
# Guess: 4 6
# Guessed incorrectly
# Iteration: 92
# True hidden state: 3 4 3
# Reading: 1 3
# Guess: 2 3
# Guessed incorrectly
# Iteration: 93
# True hidden state: 3 3 3
# Reading: 2 2
# Guess: 2 2
# Guessed incorrectly
# Iteration: 94
# True hidden state: 3 2 3
# Reading: 2 0
# Guess: 2 1
# Guessed incorrectly
# Iteration: 95
# True hidden state: 3 1 3
# Reading: 3 1
# Guess: 2 0
# Guessed incorrectly
# Iteration: 96
# True hidden state: 3 0 3
# Reading: None
# Guess: 3 0
# Guessed correctly
# Iteration: 97
# True hidden state: 2 0 2
# Reading: 4 0
# Guess: 4 0
# Guessed incorrectly
# Iteration: 98
# True hidden state: 2 1 1
# Reading: 0 3
# Guess: 2 3
# Guessed incorrectly
# Iteration: 99
# True hidden state: 2 2 1
# Reading: 1 0
# Guess: 1 1
# Guessed incorrectly
# Iteration: 100
# True hidden state: 2 3 1
# Reading: 3 2
# Guess: 2 1
# Guessed incorrectly
# Iteration: 101
# True hidden state: 2 4 1
# Reading: 3 5
# Guess: 2 4
# Guessed correctly
# Iteration: 102
# True hidden state: 2 5 1
# Reading: 2 4
# Guess: 2 5
# Guessed correctly
# Iteration: 103
# True hidden state: 2 6 1
# Reading: 2 6
# Guess: 2 6
# Guessed correctly
# Iteration: 104
# True hidden state: 2 7 1
# Reading: None
# Guess: 2 7
# Guessed correctly
# Iteration: 105
# True hidden state: 1 7 2
# Reading: None
# Guess: 1 7
# Guessed correctly
# Iteration: 106
# True hidden state: 0 7 2
# Reading: None
# Guess: 0 7
# Guessed correctly
# Iteration: 107
# True hidden state: 0 6 3
# Reading: None
# Guess: 1 7
# Guessed incorrectly
# Iteration: 108
# True hidden state: 0 5 3
# Reading: 2 6
# Guess: 2 7
# Guessed incorrectly
# Iteration: 109
# True hidden state: 0 4 3
# Reading: 0 2
# Guess: 0 4
# Guessed correctly
# Iteration: 110
# True hidden state: 1 4 0
# Reading: 0 6
# Guess: 0 5
# Guessed incorrectly
# Iteration: 111
# True hidden state: 0 4 2
# Reading: None
# Guess: 0 6
# Guessed incorrectly
# Iteration: 112
# True hidden state: 1 4 0
# Reading: 1 3
# Guess: 0 3
# Guessed incorrectly
# Iteration: 113
# True hidden state: 0 4 2
# Reading: None
# Guess: 0 2
# Guessed incorrectly
# Iteration: 114
# True hidden state: 0 3 3
# Reading: None
# Guess: 0 1
# Guessed incorrectly
# Iteration: 115
# True hidden state: 0 2 3
# Reading: None
# Guess: 0 0
# Guessed incorrectly
# Iteration: 116
# True hidden state: 0 1 3
# Reading: None
# Guess: 0 1
# Guessed correctly
# Iteration: 117
# True hidden state: 0 0 3
# Reading: None
# Guess: 0 0
# Guessed correctly
# Iteration: 118
# True hidden state: 0 1 1
# Reading: None
# Guess: 0 1
# Guessed correctly
# Iteration: 119
# True hidden state: 0 2 1
# Reading: None
# Guess: 0 2
# Guessed correctly
# Iteration: 120
# True hidden state: 1 2 0
# Reading: 1 2
# Guess: 0 1
# Guessed incorrectly
# Iteration: 121
# True hidden state: 2 2 0
# Reading: 1 1
# Guess: 0 2
# Guessed incorrectly
# Iteration: 122
# True hidden state: 3 2 0
# Reading: 3 3
# Guess: 3 2
# Guessed correctly
# Iteration: 123
# True hidden state: 2 2 2
# Reading: 2 2
# Guess: 2 2
# Guessed correctly
# Iteration: 124
# True hidden state: 2 1 3
# Reading: 1 1
# Guess: 1 2
# Guessed incorrectly
# Iteration: 125
# True hidden state: 3 1 0
# Reading: 3 2
# Guess: 4 2
# Guessed incorrectly
# Iteration: 126
# True hidden state: 4 1 0
# Reading: 4 0
# Guess: 3 0
# Guessed incorrectly
# Iteration: 127
# True hidden state: 4 2 1
# Reading: None
# Guess: 4 0
# Guessed incorrectly
# Iteration: 128
# True hidden state: 4 3 1
# Reading: 4 1
# Guess: 4 1
# Guessed incorrectly
# Iteration: 129
# True hidden state: 4 4 1
# Reading: None
# Guess: 6 0
# Guessed incorrectly
# Iteration: 130
# True hidden state: 4 5 1
# Reading: 4 5
# Guess: 4 3
# Guessed incorrectly
# Iteration: 131
# True hidden state: 4 4 3
# Reading: 2 2
# Guess: 4 4
# Guessed correctly
# Iteration: 132
# True hidden state: 4 3 3
# Reading: 3 5
# Guess: 4 5
# Guessed incorrectly
# Iteration: 133
# True hidden state: 4 2 3
# Reading: 2 3
# Guess: 2 4
# Guessed incorrectly
# Iteration: 134
# True hidden state: 4 1 3
# Reading: 3 1
# Guess: 3 2
# Guessed incorrectly
# Iteration: 135
# True hidden state: 4 0 3
# Reading: None
# Guess: 2 0
# Guessed incorrectly
# Iteration: 136
# True hidden state: 5 0 0
# Reading: 4 1
# Guess: 4 1
# Guessed incorrectly
# Iteration: 137
# True hidden state: 6 0 0
# Reading: 6 0
# Guess: 6 0
# Guessed correctly
# Iteration: 138
# True hidden state: 6 1 1
# Reading: 6 1
# Guess: 6 1
# Guessed correctly
# Iteration: 139
# True hidden state: 6 2 1
# Reading: None
# Guess: 7 1
# Guessed incorrectly
# Iteration: 140
# True hidden state: 6 3 1
# Reading: 7 1
# Guess: 7 0
# Guessed incorrectly
# Iteration: 141
# True hidden state: 6 4 1
# Reading: None
# Guess: 7 1
# Guessed incorrectly
# Iteration: 142
# True hidden state: 6 5 1
# Reading: 6 6
# Guess: 7 4
# Guessed incorrectly
# Iteration: 143
# True hidden state: 6 6 1
# Reading: None
# Guess: 7 5
# Guessed incorrectly
# Iteration: 144
# True hidden state: 6 5 3
# Reading: 4 7
# Guess: 6 5
# Guessed correctly
# Iteration: 145
# True hidden state: 7 5 0
# Reading: 7 6
# Guess: 5 5
# Guessed incorrectly
# Iteration: 146
# True hidden state: 6 5 2
# Reading: None
# Guess: 6 7
# Guessed incorrectly
# Iteration: 147
# True hidden state: 5 5 2
# Reading: 4 7
# Guess: 5 7
# Guessed incorrectly
# Iteration: 148
# True hidden state: 5 4 3
# Reading: 6 3
# Guess: 6 5
# Guessed incorrectly
# Iteration: 149
# True hidden state: 5 3 3
# Reading: None
# Guess: 6 4
# Guessed incorrectly
# Iteration: 150
# True hidden state: 5 2 3
# Reading: 6 4
# Guess: 6 3
# Guessed incorrectly
# Iteration: 151
# True hidden state: 5 1 3
# Reading: None
# Guess: 6 2
# Guessed incorrectly
# Iteration: 152
# True hidden state: 5 0 3
# Reading: None
# Guess: 7 2
# Guessed incorrectly
# Iteration: 153
# True hidden state: 5 1 1
# Reading: 6 3
# Guess: 7 3
# Guessed incorrectly
# Iteration: 154
# True hidden state: 4 1 2
# Reading: 4 0
# Guess: 5 2
# Guessed incorrectly
# Iteration: 155
# True hidden state: 3 1 2
# Reading: None
# Guess: 6 0
# Guessed incorrectly
# Iteration: 156
# True hidden state: 2 1 2
# Reading: 3 3
# Guess: 3 2
# Guessed incorrectly
# Iteration: 157
# True hidden state: 1 1 2
# Reading: None
# Guess: 3 1
# Guessed incorrectly
# Iteration: 158
# True hidden state: 0 1 2
# Reading: None
# Guess: 0 1
# Guessed correctly
# Iteration: 159
# True hidden state: 1 1 0
# Reading: 1 2
# Guess: 1 1
# Guessed correctly
# Iteration: 160
# True hidden state: 2 1 0
# Reading: 3 0
# Guess: 2 1
# Guessed correctly
# Iteration: 161
# True hidden state: 3 1 0
# Reading: 2 2
# Guess: 3 1
# Guessed correctly
# Iteration: 162
# True hidden state: 4 1 0
# Reading: None
# Guess: 4 1
# Guessed correctly
# Iteration: 163
# True hidden state: 3 1 2
# Reading: 5 3
# Guess: 5 1
# Guessed incorrectly
# Iteration: 164
# True hidden state: 2 1 2
# Reading: 3 1
# Guess: 3 2
# Guessed incorrectly
# Iteration: 165
# True hidden state: 1 1 2
# Reading: None
# Guess: 4 0
# Guessed incorrectly
# Iteration: 166
# True hidden state: 1 0 3
# Reading: None
# Guess: 3 0
# Guessed incorrectly
# Iteration: 167
# True hidden state: 1 1 1
# Reading: None
# Guess: 6 0
# Guessed incorrectly
# Iteration: 168
# True hidden state: 2 1 0
# Reading: 3 1
# Guess: 1 0
# Guessed incorrectly
# Iteration: 169
# True hidden state: 3 1 0
# Reading: 4 2
# Guess: 4 2
# Guessed incorrectly
# Iteration: 170
# True hidden state: 4 1 0
# Reading: 6 3
# Guess: 4 1
# Guessed correctly
# Iteration: 171
# True hidden state: 3 1 2
# Reading: 2 3
# Guess: 4 4
# Guessed incorrectly
# Iteration: 172
# True hidden state: 2 1 2
# Reading: None
# Guess: 4 5
# Guessed incorrectly
# Iteration: 173
# True hidden state: 1 1 2
# Reading: 0 3
# Guess: 1 3
# Guessed incorrectly
# Iteration: 174
# True hidden state: 0 1 2
# Reading: None
# Guess: 0 3
# Guessed incorrectly
# Iteration: 175
# True hidden state: 0 0 3
# Reading: None
# Guess: 0 2
# Guessed incorrectly
# Iteration: 176
# True hidden state: 0 1 1
# Reading: 0 1
# Guess: 0 1
# Guessed correctly
# Iteration: 177
# True hidden state: 0 2 1
# Reading: 2 2
# Guess: 1 1
# Guessed incorrectly
# Iteration: 178
# True hidden state: 0 3 1
# Reading: 0 4
# Guess: 0 3
# Guessed correctly
# Iteration: 179
# True hidden state: 0 4 1
# Reading: None
# Guess: 0 4
# Guessed correctly
# Iteration: 180
# True hidden state: 0 5 1
# Reading: 1 5
# Guess: 0 5
# Guessed correctly
# Iteration: 181
# True hidden state: 0 4 3
# Reading: 0 3
# Guess: 0 4
# Guessed correctly
# Iteration: 182
# True hidden state: 0 5 1
# Reading: 0 5
# Guess: 0 5
# Guessed correctly
# Iteration: 183
# True hidden state: 0 4 3
# Reading: None
# Guess: 0 6
# Guessed incorrectly
# Iteration: 184
# True hidden state: 0 3 3
# Reading: None
# Guess: 0 7
# Guessed incorrectly
# Iteration: 185
# True hidden state: 0 4 1
# Reading: 0 5
# Guess: 0 6
# Guessed incorrectly
# Iteration: 186
# True hidden state: 0 5 1
# Reading: None
# Guess: 0 5
# Guessed correctly
# Iteration: 187
# True hidden state: 1 5 0
# Reading: 1 5
# Guess: 0 4
# Guessed incorrectly
# Iteration: 188
# True hidden state: 2 5 0
# Reading: 2 5
# Guess: 2 5
# Guessed correctly
# Iteration: 189
# True hidden state: 3 5 0
# Reading: 4 5
# Guess: 3 5
# Guessed correctly
# Iteration: 190
# True hidden state: 4 5 0
# Reading: 5 6
# Guess: 4 5
# Guessed correctly
# Iteration: 191
# True hidden state: 5 5 0
# Reading: 6 3
# Guess: 5 5
# Guessed correctly
# Iteration: 192
# True hidden state: 6 5 0
# Reading: 7 7
# Guess: 6 5
# Guessed correctly
# Iteration: 193
# True hidden state: 6 4 3
# Reading: 7 5
# Guess: 7 5
# Guessed incorrectly
# Iteration: 194
# True hidden state: 6 3 3
# Reading: 5 5
# Guess: 6 5
# Guessed incorrectly
# Iteration: 195
# True hidden state: 6 2 3
# Reading: 6 3
# Guess: 5 5
# Guessed incorrectly
# Iteration: 196
# True hidden state: 6 1 3
# Reading: 7 2
# Guess: 7 2
# Guessed incorrectly
# Iteration: 197
# True hidden state: 6 0 3
# Reading: None
# Guess: 7 1
# Guessed incorrectly
# Iteration: 198
# True hidden state: 5 0 2
# Reading: 5 0
# Guess: 7 0
# Guessed incorrectly
# Iteration: 199
# True hidden state: 6 0 0
# Reading: None
# Guess: 6 0
# Guessed correctly
# Iteration: 200
# True hidden state: 6 1 1
# Reading: 4 0
# Guess: 5 0
# Guessed incorrectly
# Iteration: 201
# True hidden state: 6 2 1
# Reading: 6 1
# Guess: 4 0
# Guessed incorrectly
# Iteration: 202
# True hidden state: 6 1 3
# Reading: 6 3
# Guess: 6 3
# Guessed incorrectly
# Iteration: 203
# True hidden state: 6 0 3
# Reading: 5 1
# Guess: 5 1
# Guessed incorrectly
# Iteration: 204
# True hidden state: 6 1 1
# Reading: 6 0
# Guess: 6 1
# Guessed correctly
# Iteration: 205
# True hidden state: 6 2 1
# Reading: 6 2
# Guess: 6 2
# Guessed correctly
# Iteration: 206
# True hidden state: 6 3 1
# Reading: 7 2
# Guess: 7 2
# Guessed incorrectly
# Iteration: 207
# True hidden state: 6 4 1
# Reading: None
# Guess: 7 3
# Guessed incorrectly
# Iteration: 208
# True hidden state: 6 5 1
# Reading: 7 5
# Guess: 7 4
# Guessed incorrectly
# Iteration: 209
# True hidden state: 6 6 1
# Reading: 4 7
# Guess: 6 6
# Guessed correctly
# Iteration: 210
# True hidden state: 6 7 1
# Reading: 7 7
# Guess: 6 7
# Guessed correctly
# Iteration: 211
# True hidden state: 6 6 3
# Reading: 5 6
# Guess: 6 6
# Guessed correctly
# Iteration: 212
# True hidden state: 6 5 3
# Reading: None
# Guess: 4 7
# Guessed incorrectly
# Iteration: 213
# True hidden state: 6 4 3
# Reading: 7 6
# Guess: 7 7
# Guessed incorrectly
# Iteration: 214
# True hidden state: 6 3 3
# Reading: 6 3
# Guess: 7 4
# Guessed incorrectly
# Iteration: 215
# True hidden state: 5 3 2
# Reading: 6 3
# Guess: 7 3
# Guessed incorrectly
# Iteration: 216
# True hidden state: 4 3 2
# Reading: 4 3
# Guess: 6 1
# Guessed incorrectly
# Iteration: 217
# True hidden state: 4 4 1
# Reading: 5 4
# Guess: 4 4
# Guessed correctly
# Iteration: 218
# True hidden state: 4 5 1
# Reading: 3 5
# Guess: 3 4
# Guessed incorrectly
# Iteration: 219
# True hidden state: 4 6 1
# Reading: 4 6
# Guess: 4 6
# Guessed correctly
# Iteration: 220
# True hidden state: 4 7 1
# Reading: None
# Guess: 4 7
# Guessed correctly
# Iteration: 221
# True hidden state: 4 6 3
# Reading: 6 5
# Guess: 5 7
# Guessed incorrectly
# Iteration: 222
# True hidden state: 4 7 1
# Reading: 5 6
# Guess: 5 6
# Guessed incorrectly
# Iteration: 223
# True hidden state: 3 7 2
# Reading: None
# Guess: 7 7
# Guessed incorrectly
# Iteration: 224
# True hidden state: 2 7 2
# Reading: None
# Guess: 7 6
# Guessed incorrectly
# Iteration: 225
# True hidden state: 3 7 0
# Reading: None
# Guess: 7 7
# Guessed incorrectly
# Iteration: 226
# True hidden state: 4 7 0
# Reading: None
# Guess: 6 7
# Guessed incorrectly
# Iteration: 227
# True hidden state: 4 6 3
# Reading: None
# Guess: 7 7
# Guessed incorrectly
# Iteration: 228
# True hidden state: 4 5 3
# Reading: 6 4
# Guess: 7 4
# Guessed incorrectly
# Iteration: 229
# True hidden state: 4 6 1
# Reading: 2 7
# Guess: 4 6
# Guessed correctly
# Iteration: 230
# True hidden state: 4 7 1
# Reading: 2 7
# Guess: 3 6
# Guessed incorrectly
# Iteration: 231
# True hidden state: 5 7 0
# Reading: 6 6
# Guess: 4 6
# Guessed incorrectly
# Iteration: 232
# True hidden state: 4 7 2
# Reading: None
# Guess: 6 7
# Guessed incorrectly
# Iteration: 233
# True hidden state: 3 7 2
# Reading: 2 7
# Guess: 3 7
# Guessed correctly
# Iteration: 234
# True hidden state: 3 6 3
# Reading: 3 5
# Guess: 2 7
# Guessed incorrectly
# Iteration: 235
# True hidden state: 3 5 3
# Reading: 1 5
# Guess: 2 6
# Guessed incorrectly
# Iteration: 236
# True hidden state: 2 5 2
# Reading: 3 4
# Guess: 3 4
# Guessed incorrectly
# Iteration: 237
# True hidden state: 1 5 2
# Reading: 0 3
# Guess: 2 4
# Guessed incorrectly
# Iteration: 238
# True hidden state: 0 5 2
# Reading: 2 7
# Guess: 0 5
# Guessed correctly
# Guess: 7 6
# Guessed correctly
# Iteration: 269
# True hidden state: 7 5 3
# Reading: 7 5
# Guess: 7 5
# Guessed correctly
# Iteration: 270
# True hidden state: 7 4 3
# Reading: None
# Guess: 7 4
# Guessed correctly
# Iteration: 271
# True hidden state: 6 4 2
# Reading: 6 6
# Guess: 7 5
# Guessed incorrectly
# Iteration: 272
# True hidden state: 5 4 2
# Reading: 7 4
# Guess: 7 4
# Guessed incorrectly
# Iteration: 273
# True hidden state: 4 4 2
# Reading: 4 4
# Guess: 5 5
# Guessed incorrectly
# Iteration: 274
# True hidden state: 3 4 2
# Reading: 5 3
# Guess: 5 4
# Guessed incorrectly
# Iteration: 275
# True hidden state: 2 4 2
# Reading: 3 4
# Guess: 4 4
# Guessed incorrectly
# Iteration: 276
# True hidden state: 1 4 2
# Reading: 2 4
# Guess: 3 4
# Guessed incorrectly
# Iteration: 277
# True hidden state: 1 3 3
# Reading: None
# Guess: 0 4
# Guessed incorrectly
# Iteration: 278
# True hidden state: 1 2 3
# Reading: 2 3
# Guess: 1 4
# Guessed incorrectly
# Iteration: 279
# True hidden state: 1 1 3
# Reading: 3 3
# Guess: 2 4
# Guessed incorrectly
# Iteration: 280
# True hidden state: 1 0 3
# Reading: 1 0
# Guess: 2 1
# Guessed incorrectly
# Iteration: 281
# True hidden state: 1 1 1
# Reading: 1 1
# Guess: 1 1
# Guessed correctly
# Iteration: 282
# True hidden state: 2 1 0
# Reading: 4 0
# Guess: 3 0
# Guessed incorrectly
# Iteration: 283
# True hidden state: 3 1 0
# Reading: None
# Guess: 4 0
# Guessed incorrectly
# Iteration: 284
# True hidden state: 4 1 0
# Reading: 6 0
# Guess: 5 0
# Guessed incorrectly
# Iteration: 285
# True hidden state: 3 1 2
# Reading: 4 0
# Guess: 6 0
# Guessed incorrectly
# Iteration: 286
# True hidden state: 2 1 2
# Reading: 4 3
# Guess: 5 2
# Guessed incorrectly
# Iteration: 287
# True hidden state: 1 1 2
# Reading: 2 3
# Guess: 4 4
# Guessed incorrectly
# Iteration: 288
# True hidden state: 1 0 3
# Reading: 2 0
# Guess: 2 1
# Guessed incorrectly
# Iteration: 289
# True hidden state: 1 1 1
# Reading: 0 2
# Guess: 1 1
# Guessed correctly
# Iteration: 290
# True hidden state: 1 2 1
# Reading: 0 2
# Guess: 0 1
# Guessed incorrectly
# Iteration: 291
# True hidden state: 1 3 1
# Reading: 0 4
# Guess: 0 4
# Guessed incorrectly
# Iteration: 292
# True hidden state: 1 2 3
# Reading: 0 2
# Guess: 0 3
# Guessed incorrectly
# Iteration: 293
# True hidden state: 1 1 3
# Reading: 1 0
# Guess: 0 2
# Guessed incorrectly
# Iteration: 294
# True hidden state: 1 0 3
# Reading: 2 0
# Guess: 1 0
# Guessed correctly
# Iteration: 295
# True hidden state: 0 0 2
# Reading: None
# Guess: 0 0
# Guessed correctly
# Iteration: 296
# True hidden state: 0 1 1
# Reading: None
# Guess: 1 0
# Guessed incorrectly
# Iteration: 297
# True hidden state: 0 2 1
# Reading: None
# Guess: 0 0
# Guessed incorrectly
# Iteration: 298
# True hidden state: 0 1 3
# Reading: 2 3
# Guess: 0 1
# Guessed correctly
# Iteration: 299
# True hidden state: 0 0 3
# Reading: None
# Guess: 0 2
# Guessed incorrectly
# Iteration: 300
# True hidden state: 0 1 1
# Reading: 0 1
# Guess: 0 1
# Guessed correctly
# Iteration: 301
# True hidden state: 0 0 3
# Reading: None
# Guess: 0 0
# Guessed correctly
# Iteration: 302
# True hidden state: 0 1 1
# Reading: 2 1
# Guess: 1 0
# Guessed incorrectly
# Iteration: 303
# True hidden state: 0 0 3
# Reading: 1 1
# Guess: 2 0
# Guessed incorrectly
# Iteration: 304
# True hidden state: 0 1 1
# Reading: None
# Guess: 1 0
# Guessed incorrectly
# Iteration: 305
# True hidden state: 1 1 0
# Reading: 1 0
# Guess: 0 0
# Guessed incorrectly
# Iteration: 306
# True hidden state: 2 1 0
# Reading: 2 0
# Guess: 1 0
# Guessed incorrectly
# Iteration: 307
# True hidden state: 3 1 0
# Reading: 2 1
# Guess: 2 0
# Guessed incorrectly
# Iteration: 308
# True hidden state: 2 1 2
# Reading: 1 0
# Guess: 1 0
# Guessed incorrectly
# Iteration: 309
# True hidden state: 1 1 2
# Reading: None
# Guess: 0 0
# Guessed incorrectly
# Iteration: 310
# True hidden state: 0 1 2
# Reading: 0 2
# Guess: 0 1
# Guessed correctly
# Iteration: 311
# True hidden state: 0 0 3
# Reading: None
# Guess: 0 2
# Guessed incorrectly
# Iteration: 312
# True hidden state: 0 1 1
# Reading: 0 1
# Guess: 0 1
# Guessed correctly
# Iteration: 313
# True hidden state: 1 1 0
# Reading: None
# Guess: 0 0
# Guessed incorrectly
# Iteration: 314
# True hidden state: 2 1 0
# Reading: None
# Guess: 0 1
# Guessed incorrectly
# Iteration: 315
# True hidden state: 3 1 0
# Reading: 4 0
# Guess: 4 0
# Guessed incorrectly
# Iteration: 316
# True hidden state: 4 1 0
# Reading: 4 1
# Guess: 5 0
# Guessed incorrectly
# Iteration: 317
# True hidden state: 5 1 0
# Reading: 5 1
# Guess: 5 1
# Guessed correctly
# Iteration: 318
# True hidden state: 6 1 0
# Reading: None
# Guess: 7 0
# Guessed incorrectly
# Iteration: 319
# True hidden state: 7 1 0
# Reading: 7 0
# Guess: 6 0
# Guessed incorrectly
# Iteration: 320
# True hidden state: 7 2 1
# Reading: 7 0
# Guess: 7 0
# Guessed incorrectly
# Iteration: 321
# True hidden state: 7 1 3
# Reading: None
# Guess: 7 1
# Guessed correctly
# Iteration: 322
# True hidden state: 7 0 3
# Reading: None
# Guess: 7 2
# Guessed incorrectly
# Iteration: 323
# True hidden state: 6 0 2
# Reading: None
# Guess: 7 1
# Guessed incorrectly
# Iteration: 324
# True hidden state: 5 0 2
# Reading: None
# Guess: 7 0
# Guessed incorrectly
# Iteration: 325
# True hidden state: 4 0 2
# Reading: None
# Guess: 7 1
# Guessed incorrectly
# Iteration: 326
# True hidden state: 3 0 2
# Reading: 5 0
# Guess: 5 0
# Guessed incorrectly
# True hidden state: 2 2 2
# Reading: 2 3
# Guess: 2 2
# Guessed correctly
# Iteration: 416
# True hidden state: 2 1 3
# Reading: 3 2
# Guess: 3 2
# Guessed incorrectly
# Iteration: 417
# True hidden state: 2 0 3
# Reading: 2 1
# Guess: 2 2
# Guessed incorrectly
# Iteration: 418
# True hidden state: 2 1 1
# Reading: 3 2
# Guess: 3 2
# Guessed incorrectly
# Iteration: 419
# True hidden state: 2 2 1
# Reading: 2 2
# Guess: 2 2
# Guessed correctly
# Iteration: 420
# True hidden state: 2 3 1
# Reading: 4 5
# Guess: 3 4
# Guessed incorrectly
# Iteration: 421
# True hidden state: 2 4 1
# Reading: 3 6
# Guess: 3 5
# Guessed incorrectly
# Iteration: 422
# True hidden state: 3 4 0
# Reading: 2 6
# Guess: 3 6
# Guessed incorrectly
# Iteration: 423
# True hidden state: 3 5 1
# Reading: 4 6
# Guess: 3 7
# Guessed incorrectly
# Iteration: 424
# True hidden state: 3 6 1
# Reading: 2 4
# Guess: 3 6
# Guessed correctly
# Iteration: 425
# True hidden state: 3 7 1
# Reading: 4 7
# Guess: 3 5
# Guessed incorrectly
# Iteration: 426
# True hidden state: 3 6 3
# Reading: 3 4
# Guess: 3 4
# Guessed incorrectly
# Iteration: 427
# True hidden state: 3 7 1
# Reading: 1 6
# Guess: 1 5
# Guessed incorrectly
# Iteration: 428
# True hidden state: 2 7 2
# Reading: None
# Guess: 0 5
# Guessed incorrectly
# Iteration: 429
# True hidden state: 1 7 2
# Reading: None
# Guess: 0 6
# Guessed incorrectly
# Iteration: 430
# True hidden state: 1 6 3
# Reading: 0 5
# Guess: 0 5
# Guessed incorrectly
# Iteration: 431
# True hidden state: 1 5 3
# Reading: 3 3
# Guess: 1 5
# Guessed correctly
# Iteration: 432
# True hidden state: 1 4 3
# Reading: None
# Guess: 1 4
# Guessed correctly
# Iteration: 433
# True hidden state: 1 3 3
# Reading: 1 1
# Guess: 1 1
# Guessed incorrectly
# Iteration: 434
# True hidden state: 1 4 1
# Reading: 2 3
# Guess: 1 2
# Guessed incorrectly
# Iteration: 435
# True hidden state: 1 5 1
# Reading: None
# Guess: 1 1
# Guessed incorrectly
# Iteration: 436
# True hidden state: 1 6 1
# Reading: None
# Guess: 1 0
# Guessed incorrectly
# Iteration: 437
# True hidden state: 1 7 1
# Reading: None
# Guess: 0 0
# Guessed incorrectly
# Iteration: 438
# True hidden state: 2 7 0
# Reading: 0 7
# Guess: 0 7
# Guessed incorrectly
# Iteration: 439
# True hidden state: 3 7 0
# Reading: 3 7
# Guess: 1 7
# Guessed incorrectly
# Iteration: 440
# True hidden state: 4 7 0
# Reading: 3 6
# Guess: 2 7
# Guessed incorrectly
# Iteration: 441
# True hidden state: 5 7 0
# Reading: 5 7
# Guess: 4 6
# Guessed incorrectly
# Iteration: 442
# True hidden state: 6 7 0
# Reading: 4 5
# Guess: 5 6
# Guessed incorrectly
# Iteration: 443
# True hidden state: 7 7 0
# Reading: 7 7
# Guess: 6 6
# Guessed incorrectly
# Iteration: 444
# True hidden state: 7 6 3
# Reading: 7 4
# Guess: 7 6
# Guessed correctly
# Iteration: 445
# True hidden state: 6 6 2
# Reading: 5 5
# Guess: 7 5
# Guessed incorrectly
# Iteration: 446
# True hidden state: 5 6 2
# Reading: 3 5
# Guess: 5 6
# Guessed correctly
# Iteration: 447
# True hidden state: 4 6 2
# Reading: 5 7
# Guess: 4 6
# Guessed correctly
# Iteration: 448
# True hidden state: 4 5 3
# Reading: 6 4
# Guess: 5 6
# Guessed incorrectly
# Iteration: 449
# True hidden state: 4 4 3
# Reading: 2 4
# Guess: 4 4
# Guessed correctly
# Iteration: 450
# True hidden state: 3 4 2
# Reading: 3 4
# Guess: 4 3
# Guessed incorrectly
# Iteration: 451
# True hidden state: 2 4 2
# Reading: 3 5
# Guess: 2 4
# Guessed correctly
# Iteration: 452
# True hidden state: 1 4 2
# Reading: 0 4
# Guess: 1 4
# Guessed correctly
# Iteration: 453
# True hidden state: 1 5 1
# Reading: 0 3
# Guess: 0 4
# Guessed incorrectly
# Iteration: 454
# True hidden state: 1 6 1
# Reading: None
# Guess: 0 3
# Guessed incorrectly
# Iteration: 455
# True hidden state: 1 7 1
# Reading: None
# Guess: 0 2
# Guessed incorrectly
# Iteration: 456
# True hidden state: 0 7 2
# Reading: 0 7
# Guess: 0 7
# Guessed correctly
# Iteration: 457
# True hidden state: 0 6 3
# Reading: None
# Guess: 0 6
# Guessed correctly
# Iteration: 458
# True hidden state: 1 6 0
# Reading: 0 4
# Guess: 0 5
# Guessed incorrectly
# Iteration: 459
# True hidden state: 2 6 0
# Reading: 4 6
# Guess: 2 6
# Guessed correctly
# Iteration: 460
# True hidden state: 3 6 0
# Reading: 1 5
# Guess: 3 6
# Guessed correctly
# Iteration: 461
# True hidden state: 2 6 2
# Reading: 3 6
# Guess: 4 6
# Guessed incorrectly
# Iteration: 462
# True hidden state: 1 6 2
# Reading: None
# Guess: 5 6
# Guessed incorrectly
# Iteration: 463
# True hidden state: 0 6 2
# Reading: None
# Guess: 6 6
# Guessed incorrectly
# Iteration: 464
# True hidden state: 1 6 0
# Reading: 2 7
# Guess: 2 7
# Guessed incorrectly
# Iteration: 465
# True hidden state: 2 6 0
# Reading: 1 6
# Guess: 1 7
# Guessed incorrectly
# Iteration: 466
# True hidden state: 3 6 0
# Reading: 4 7
# Guess: 4 7
# Guessed incorrectly
# Iteration: 467
# True hidden state: 4 6 0
# Reading: 6 4
# Guess: 4 6
# Guessed correctly
# Iteration: 468
# True hidden state: 4 7 1
# Reading: None
# Guess: 5 6
# Guessed incorrectly
# Iteration: 469
# True hidden state: 5 7 0
# Reading: None
# Guess: 6 6
# Guessed incorrectly
# Iteration: 470
# True hidden state: 6 7 0
# Reading: 7 6
# Guess: 7 6
# Guessed incorrectly
# Iteration: 471
# True hidden state: 7 7 0
# Reading: None
# Guess: 7 7
# Guessed correctly
# Iteration: 472
# True hidden state: 6 7 2
# Reading: 6 7
# Guess: 6 7
# Guessed correctly
# Iteration: 473
# True hidden state: 5 7 2
# Reading: 7 6
# Guess: 7 5
# Guessed incorrectly
# Iteration: 474
# True hidden state: 4 7 2
# Reading: None
# Guess: 7 6
# Guessed incorrectly
# Iteration: 475
# True hidden state: 3 7 2
# Reading: None
# Guess: 7 7
# Guessed incorrectly
# Iteration: 476
# True hidden state: 2 7 2
# Reading: None
# Guess: 7 6
# Guessed incorrectly
# Iteration: 477
# True hidden state: 1 7 2
# Reading: None
# Guess: 7 7
# Guessed incorrectly
# Iteration: 478
# True hidden state: 0 7 2
# Reading: None
# Guess: 7 6
# Guessed incorrectly
# Iteration: 479
# True hidden state: 0 6 3
# Reading: 0 5
# Guess: 0 6
# Guessed correctly
# Iteration: 480
# True hidden state: 0 5 3
# Reading: 2 3
# Guess: 0 5
# Guessed correctly
# Iteration: 481
# True hidden state: 0 4 3
# Reading: None
# Guess: 0 4
# Guessed correctly
# Iteration: 482
# True hidden state: 0 3 3
# Reading: 0 2
# Guess: 0 3
# Guessed correctly
# Iteration: 483
# True hidden state: 0 2 3
# Reading: 1 2
# Guess: 0 2
# Guessed correctly
# Iteration: 484
# True hidden state: 0 1 3
# Reading: None
# Guess: 0 1
# Guessed correctly
# Iteration: 485
# True hidden state: 0 0 3
# Reading: 0 2
# Guess: 0 2
# Guessed incorrectly
# Iteration: 486
# True hidden state: 0 1 1
# Reading: None
# Guess: 0 1
# Guessed correctly
# Iteration: 487
# True hidden state: 0 2 1
# Reading: None
# Guess: 0 0
# Guessed incorrectly
# Iteration: 488
# True hidden state: 1 2 0
# Reading: None
# Guess: 0 1
# Guessed incorrectly
# Iteration: 489
# True hidden state: 2 2 0
# Reading: 2 1
# Guess: 2 0
# Guessed incorrectly
# Iteration: 490
# True hidden state: 3 2 0
# Reading: None
# Guess: 3 0
# Guessed incorrectly
# Iteration: 491
# True hidden state: 4 2 0
# Reading: 6 0
# Guess: 6 0
# Guessed incorrectly
# Iteration: 492
# True hidden state: 3 2 2
# Reading: 4 1
# Guess: 5 0
# Guessed incorrectly
# Iteration: 493
# True hidden state: 2 2 2
# Reading: 0 0
# Guess: 2 0
# Guessed incorrectly
# Iteration: 494
# True hidden state: 1 2 2
# Reading: None
# Guess: 1 0
# Guessed incorrectly
# Iteration: 495
# True hidden state: 0 2 2
# Reading: None
# Guess: 0 0
# Guessed incorrectly
# Iteration: 496
# True hidden state: 0 3 1
# Reading: 2 1
# Guess: 1 0
# Guessed incorrectly
# Iteration: 497
# True hidden state: 0 4 1
# Reading: None
# Guess: 2 0
# Guessed incorrectly
# Iteration: 498
# True hidden state: 0 5 1
# Reading: 1 3
# Guess: 0 3
# Guessed incorrectly
# Iteration: 499
# True hidden state: 1 5 0
# Reading: 0 5
# Guess: 0 4
# Guessed incorrectly
# Observations:
